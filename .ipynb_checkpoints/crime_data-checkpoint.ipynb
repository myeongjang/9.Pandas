# %%
import pandas as pd
import numpy as np 
import matplotlib as plt
import os

# %%
crime_data = pd.read_csv('../Crimes_-_2001_to_present.csv',encoding = 'ASCII')
# Out:
# C:\Users\Playdata\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
crime_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4451247 entries, 0 to 4451246
# Data columns (total 22 columns):
# ID                      int64
# Case Number             object
# Date                    object
# Block                   object
# IUCR                    object
# Primary Type            object
# Description             object
# Location Description    object
# Arrest                  object
# Domestic                object
# Beat                    float64
# District                float64
# Ward                    float64
# Community Area          float64
# FBI Code                object
# X Coordinate            float64
# Y Coordinate            float64
# Year                    float64
# Updated On              object
# Latitude                float64
# Longitude               float64
# Location                object
# dtypes: float64(9), int64(1), object(12)
# memory usage: 747.1+ MB

# %%
crime_data.describe()
# Out:
#                  ID          Beat      District          Ward  Community Area  \
# count  4.451247e+06  4.451246e+06  4.451232e+06  3.837529e+06    3.836885e+06
# mean   6.648522e+06  1.186256e+03  1.131313e+01  2.275189e+01    3.747781e+01
# std    3.395356e+06  7.022244e+02  6.945136e+00  1.384399e+01    2.150799e+01
# min    6.340000e+02  1.110000e+02  1.000000e+00  1.000000e+00    0.000000e+00
# 25%    2.708312e+06  6.210000e+02  6.000000e+00  1.000000e+01    2.300000e+01
# 50%    7.792782e+06  1.034000e+03  1.000000e+01  2.300000e+01    3.200000e+01
# 75%    9.570036e+06  1.731000e+03  1.700000e+01  3.400000e+01    5.700000e+01
# max    1.137408e+07  2.535000e+03  3.100000e+01  5.000000e+01    7.700000e+01
#
#        X Coordinate  Y Coordinate          Year      Latitude     Longitude
# count  4.397517e+06  4.397517e+06  4.451246e+06  4.397517e+06  4.397517e+06
# mean   1.164495e+06  1.885834e+06  2.009075e+03  4.184232e+01 -8.767187e+01
# ...

# %%
crime_data[['Primary Type','Description','Beat','District']].head(100)
# Out:
#               Primary Type                    Description    Beat  District
# 0                  BATTERY            AGGRAVATED: HANDGUN  1111.0      11.0
# 1            OTHER OFFENSE               PAROLE VIOLATION   725.0       7.0
# 2                  BATTERY        DOMESTIC BATTERY SIMPLE   222.0       2.0
# 3                  BATTERY                         SIMPLE   225.0       2.0
# 4                  ROBBERY                 ARMED: HANDGUN  1113.0      11.0
# 5                  BATTERY                         SIMPLE   223.0       2.0
# 6                  BATTERY        DOMESTIC BATTERY SIMPLE   733.0       7.0
# 7                  BATTERY        DOMESTIC BATTERY SIMPLE   213.0       2.0
# 8                NARCOTICS   POSS: CANNABIS 30GMS OR LESS   912.0       9.0
# 9                  BATTERY                         SIMPLE   511.0       5.0
# 10         CRIMINAL DAMAGE                     TO VEHICLE   533.0       5.0
# ...

# %%
crime_data.tail(100)
# Out:
#                ID Case Number                    Date  \
# 4451147   2926788    HJ610325  09/05/2003 09:45:39 PM
# 4451148   2926789    HJ610326  09/05/2003 09:33:41 PM
# 4451149   2926790    HJ594915  08/29/2003 01:15:00 PM
# 4451150   2926793    HJ610585  09/05/2003 11:00:00 PM
# 4451151  10980047    JA305151  06/13/2017 02:07:00 PM
# 4451152   2926794    HJ608977  09/05/2003 10:45:39 AM
# 4451153   2926795    HJ608430  09/05/2003 12:30:00 AM
# 4451154   2926796    HJ610831  09/06/2003 12:00:00 AM
# 4451155   2926797    HJ609432  09/05/2003 02:30:00 PM
# 4451156   2926798    HJ609254  09/05/2003 01:03:00 PM
# 4451157   2926800    HJ610154  08/08/2003 07:30:00 PM
# 4451158   2926801    HJ608907  09/04/2003 10:00:00 PM
# 4451159   2926802    HJ610836  09/06/2003 05:00:00 AM
# 4451160   2926803    HJ607937  09/04/2003 06:40:04 PM
# 4451161   2926804    HJ610686  09/06/2003 01:55:00 AM
# 4451162   2926805    HJ609783  09/05/2003 05:35:00 PM
# ...

# %%
dummy = crime_data.copy()
dummy.isnull().any()
# Out:
# ID                      False
# Case Number              True
# Date                    False
# Block                    True
# IUCR                     True
# Primary Type             True
# Description              True
# Location Description     True
# Arrest                   True
# Domestic                 True
# Beat                     True
# District                 True
# Ward                     True
# Community Area           True
# FBI Code                 True
# X Coordinate             True
# Y Coordinate             True
# Year                     True
# Updated On               True
# Latitude                 True
# Longitude                True
# Location                 True
# dtype: bool

# %%
dummy.loc[[dummy.isnull() == True]].head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-1a73b4828d62> in <module>()
# ----> 1 dummy.loc[[dummy.isnull() == True]].head()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1865             self._validate_key(key, axis)
#    1866             return self._get_slice_axis(key, axis=axis)
# -> 1867         elif com.is_bool_indexer(key):
#    1868             return self._getbool_axis(key, axis=axis)
#    1869         elif is_list_like_indexer(key):
#
# ...
